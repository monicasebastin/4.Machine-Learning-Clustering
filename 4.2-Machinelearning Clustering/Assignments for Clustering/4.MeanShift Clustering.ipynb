# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
dataset=pd.read_csv("Mall_Customers.csv")
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
x=dataset.iloc[:,3:5].values
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import estimate_bandwidth, MeanShift

bandwidth = estimate_bandwidth(x, quantile=0.2, n_samples=500)
ms = MeanShift(bandwidth=bandwidth)
ms.fit(x)
labels = ms.labels_
# Out:
# C:\Users\edwin\anaconda3\envs\MonicaAI\lib\site-packages\sklearn\neighbors\base.py:441: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   old_joblib = LooseVersion(joblib_version) < LooseVersion('0.12')
# C:\Users\edwin\anaconda3\envs\MonicaAI\lib\site-packages\sklearn\neighbors\base.py:441: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   old_joblib = LooseVersion(joblib_version) < LooseVersion('0.12')
# C:\Users\edwin\anaconda3\envs\MonicaAI\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# C:\Users\edwin\anaconda3\envs\MonicaAI\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# ...

# %%
labels = ms.labels_
cluster_centers = ms.cluster_centers_

# %%
supervised = pd.DataFrame(x)
supervised['Cluster_group'] = labels
supervised
# Out:
#        0   1  Cluster_group
# 0     15  39              0
# 1     15  81              0
# 2     16   6              0
# 3     16  77              0
# 4     17  40              0
# ..   ...  ..            ...
# 195  120  79              1
# 196  126  28              2
# 197  126  74              1
# 198  137  18              2
# 199  137  83              1
#
# [200 rows x 3 columns]

# %%
supervised.to_csv("MeanShift.csv",index=False)

# %%
import seaborn as sns
sns.scatterplot(
    data=supervised,
    x=supervised.columns[0],
    y=supervised.columns[1],
    hue='Cluster_group',
    palette='Set1',
    s=50
)

# Plot cluster centers
plt.scatter(
    cluster_centers[:, 0],
    cluster_centers[:, 1],
    c='black',
    s=150,
    marker='x',
    label='Centers'
)

plt.title("MeanShift Clustering with Cluster Centers")
plt.legend()
plt.show()

# %%
cluster=len(np.unique(labels))
from sklearn.metrics import silhouette_score
score=silhouette_score(x,labels,sample_size=1000,random_state=42)
print(f"cluster size={cluster},Score={score}")
# Out:
# cluster size=3,Score=0.4620356204354657
